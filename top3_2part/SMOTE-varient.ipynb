# %%
import smote_variants as sv

# %%
import smote_variants as sv
from sklearn.datasets import make_classification

X, y = make_classification(n_classes=2, class_sep=2,
                           weights=[0.1,0.9], n_informative=2, n_redundant=0, flip_y=0,
                           n_features=5, n_clusters_per_class=1, n_samples=100, random_state=9)


#sv.polynom_fit_SMOTE(proportion=1.0, topology='star', random_state=None)
# sv.ProWSyn()
oversampler= sv.polynom_fit_SMOTE(proportion=1.0, topology='star', random_state=None)
X_samp, y_samp= oversampler.sample(X, y)
# Out:
# 2021-04-06 10:52:22,106:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None}")

# %%
X_samp
# Out:
# array([[ 8.22818188e-01,  9.59605780e-02, -9.65722441e-01,
#          3.92314750e-01,  5.77969840e-02],
#        [-7.32559544e-01,  4.05449394e+00,  7.39348433e-01,
#          3.66236122e+00, -1.34297965e-02],
#        [-5.40431264e-01,  3.52323770e+00,  1.11190408e+00,
#          3.34537053e+00,  1.18490098e+00],
#        [-2.36263564e-01,  1.70968868e+00, -4.29879614e-01,
#          1.66601149e+00, -4.92256560e-01],
#        [-1.14481707e-01,  3.52311229e+00,  1.74465825e-01,
#          3.16286572e+00, -1.01870552e+00],
#        [-1.21305955e-01,  1.41242662e+00,  1.00198968e+00,
#          1.81879181e+00, -8.60374344e-01],
#        [ 1.21028211e-01,  3.45860885e+00, -2.71737608e-01,
#          3.19689248e+00,  5.36545327e-01],
#        [ 4.86334552e-01, -2.07422547e+00, -2.14632081e-01,
#          2.48803464e+00,  1.38367964e+00],
#        [ 1.15633843e+00,  4.66647515e-01, -8.20827156e-01,
#          6.51219023e-01,  1.83820642e-03],
# ...

# %%
from collections import Counter
counter = Counter(y)

# %%
counter
# Out:
# Counter({1: 90, 0: 10})

# %%
from collections import Counter
counter = Counter(y_samp)

# %%
counter
# Out:
# Counter({1: 90, 0: 90})
