# %%
c=Counter('hello,world')
c
# Out:
# Counter({'h': 1, 'e': 1, 'l': 3, 'o': 2, ',': 1, 'w': 1, 'r': 1, 'd': 1})

# %%
import sklearn
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import BorderlineSMOTE
X, y = make_classification(n_classes=3, class_sep=2,
                           weights=[0.2,0.3,0.5], n_informative=3, n_redundant=0, flip_y=0,
                           n_features=3, n_clusters_per_class=1, n_samples=100, random_state=9)
print('Original dataset shape %s' % Counter(y))
sm = BorderlineSMOTE(random_state=42,kind="borderline-1")
X_res, y_res = sm.fit_resample(X, y)
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Original dataset shape Counter({2: 50, 1: 30, 0: 20})
# Resampled dataset shape Counter({2: 50, 1: 30, 0: 20})

# %%
X
# Out:
# array([[-1.10402065, -2.52444767,  1.19998713],
#        [-1.02938031,  3.03342072, -2.76671628],
#        [-2.36269439, -1.15209199,  1.74114973],
#        [-1.65493099, -3.0005582 ,  1.17716737],
#        [-2.14872458, -2.07748222,  1.60570775],
#        [-1.66335018,  2.38679925, -1.87685441],
#        [-2.87130957,  1.22578013, -1.19833678],
#        [-2.92945425, -1.93182759,  2.6842471 ],
#        [-2.39624684, -1.64344828,  2.43586553],
#        [-0.86528355,  3.22430277, -2.55068108],
#        [ 2.96157145,  2.81348316,  2.81915451],
#        [-1.59165699, -2.8144934 ,  1.11194305],
#        [-3.33512382,  0.75832195, -1.23511779],
#        [-1.76996348, -1.93006905,  1.56109374],
#        [ 1.58365377,  0.93905178,  1.68121288],
#        [-1.01229201, -3.46390114,  1.88865337],
#        [ 1.88904898,  2.19021219,  3.37821095],
#        [-3.33835794,  0.50539897, -1.32656645],
#        [-2.31015646, -1.36631323,  2.64291962],
#        [-2.54820997, -2.44156151,  2.97501905],
#        [-1.60829792,  2.66371274, -1.9650202 ],
#        [ 3.55693308,  3.31676168,  2.14879104],
#        [ 3.24561461,  2.75548532,  2.85723168],
#        [-2.67653733, -0.5408601 ,  2.34859742],
#        [-3.29172774, -2.46453261,  3.60869947],
#        [ 0.1335981 , -3.86270272,  0.32016338],
#        [-2.054563  , -3.12923444,  1.86321431],
#        [-2.54449488, -1.15399035,  2.37821017],
#        [ 3.01822554,  2.39530223,  2.20855759],
#        [-2.1733914 ,  1.93382728, -1.80893513],
#        [-1.23597951,  2.82429683, -2.26295224],
#        [-1.27088343,  2.64552794, -2.47098162],
#        [-3.93539583, -0.83450718,  4.04333639],
#        [-2.24954728, -1.33988065,  2.56308233],
#        [-3.02759794,  0.90440647, -1.70557575],
#        [-2.43655266,  1.52105167, -1.63181804],
#        [-0.47469345, -3.71337342,  0.46044608],
#        [-4.22014669, -0.03035215,  3.18535134],
#        [ 2.72516791,  2.62165738,  2.44828397],
#        [ 4.22444359,  2.32014575,  1.70560763],
#        [ 5.2956702 ,  2.80259945,  2.52541569],
#        [-3.07599423, -1.22961614,  3.05823084],
#        [-1.85679589, -2.61464624,  1.73709087],
#        [-3.16863052, -0.59899861,  2.9500797 ],
#        [-3.4607546 ,  0.70881522, -1.59279072],
#        [-1.62714953, -2.60389588,  1.71871584],
#        [-0.336146  , -2.8635928 ,  1.12327585],
#        [ 1.38095211,  2.4327131 ,  1.12333389],
#        [-2.40424802,  1.42552966, -1.92507107],
#        [-2.41884693, -1.78986736,  2.21349127],
#        [ 3.51624794,  1.68299562,  1.46745252],
#        [-2.25936218, -1.39212   ,  2.26133548],
#        [-0.04527491,  1.08146048,  1.13358783],
#        [ 1.54471495,  2.0277439 ,  1.92456783],
#        [-2.25008992, -1.69207636,  2.27081785],
#        [-2.52619324,  1.77960854, -1.14413473],
#        [ 1.33555785,  1.98756248,  2.88343084],
#        [ 1.16795788,  2.82657781,  2.95253372],
#        [-2.40224165, -1.16030321,  2.09517552],
#        [-2.18861963,  1.99952585, -1.90696378],
#        [-2.29235416, -1.80433157,  2.18915352],
#        [-2.89590308, -1.68414197,  2.41316775],
#        [-2.32500218, -3.15958827,  2.48707118],
#        [ 0.65863223,  4.70790554, -3.07335753],
#        [-2.55923085, -0.64309336,  2.66615717],
#        [-0.7135066 , -2.17132877,  1.04172225],
#        [-2.56875708,  1.42147029, -1.7103622 ],
#        [-2.62997784, -1.07168684,  2.61605803],
#        [-3.47151394,  0.5786248 , -1.19966495],
#        [-3.53534047, -0.53395927,  3.29533004],
#        [-2.49065518, -1.59935741,  2.07294419],
#        [-1.52308595, -2.77180784,  1.52123517],
#        [-1.85185135,  1.81241298, -2.46248058],
#        [-2.31360557,  1.56873137, -1.63687131],
#        [-0.20259398,  3.8856178 , -3.20411934],
#        [-2.30096904, -2.96597941,  2.54838319],
#        [-1.62787945,  2.61023209, -2.17313944],
#        [-2.48973825,  1.51273913, -2.35867981],
#        [-2.35136739, -0.9993963 ,  2.606534  ],
#        [ 0.703862  ,  1.41657004,  2.7065249 ],
#        [-2.77935578, -2.18775403,  2.09520891],
#        [-0.54349203, -3.37436321,  1.0677716 ],
#        [ 1.70929848,  1.92360861,  3.00986127],
#        [-3.14222731, -0.57819206,  2.53713965],
#        [-3.86492012,  0.13390253, -1.32088404],
#        [-2.4653039 , -0.75036722,  2.39146999],
#        [-1.23754344,  2.85979663, -2.4463309 ],
#        [-1.94303539, -1.78555844,  1.17358527],
#        [-4.2635406 , -0.18270592,  4.21790307],
#        [ 0.91555925,  1.42750366,  0.6618176 ],
#        [-1.27472407, -3.22741591,  1.41131307],
#        [-2.46186798,  1.57322468, -1.25526904],
#        [-0.55724793,  1.12264604,  1.45367037],
#        [-3.61080719, -1.05583878,  3.09871647],
#        [ 0.74054569,  1.26234383,  3.3675683 ],
#        [-0.81557585, -2.47272279,  1.33234193],
#        [-2.01099255,  1.90371568, -1.80433846],
#        [-1.6148176 ,  2.21091603, -2.189417  ],
#        [-2.21662516,  1.7148302 , -2.16466526],
#        [-3.34070604, -0.97943969,  3.04350444]])

# %%
n_classes = 3
X, y = make_classification(n_samples=150, n_classes=n_classes,
                               n_features=5, n_informative=3, n_redundant=0,
                               random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-91a3ae69145a> in <module>
#       1 n_classes = 3
# ----> 2 X, y = make_classification(n_samples=150, n_classes=n_classes,
#       3                                n_features=5, n_informative=3, n_redundant=0,
#       4                                random_state=0)
#
# NameError: name 'make_classification' is not defined

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], marker='o', c=y)

# %%
plt.scatter(X_res[:, 0], X_res[:, 1], marker='o',c=y_res)

# %%
sm = BorderlineSMOTE(random_state=42,kind="borderline-1")
X_res, y_res = sm.fit_resample(X, y)

# %%
from imblearn.over_sampling import SMOTE
counter = Counter(y)
counter
sm = SMOTE()
X_res, y_res = sm.fit_resample(X, y)
over_counter = Counter(y_res)
over_counter
# Out:
# Counter({2: 50, 1: 50, 0: 50})

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], marker='o', c=y)

# %%
import pandas as pd 
p = pd.DataFrame(X,y)
p
# Out:
#            0         1         2
# 2  -1.104021 -2.524448  1.199987
# 1  -1.029380  3.033421 -2.766716
# 2  -2.362694 -1.152092  1.741150
# 2  -1.654931 -3.000558  1.177167
# 2  -2.148725 -2.077482  1.605708
# ..       ...       ...       ...
# 2  -0.815576 -2.472723  1.332342
# 1  -2.010993  1.903716 -1.804338
# 1  -1.614818  2.210916 -2.189417
# 1  -2.216625  1.714830 -2.164665
# 2  -3.340706 -0.979440  3.043504
#
# [100 rows x 3 columns]

# %%
X_res[:, 1]
# Out:
# array([-2.52444767,  3.03342072, -1.15209199, -3.0005582 , -2.07748222,
#         2.38679925,  1.22578013, -1.93182759, -1.64344828,  3.22430277,
#         2.81348316, -2.8144934 ,  0.75832195, -1.93006905,  0.93905178,
#        -3.46390114,  2.19021219,  0.50539897, -1.36631323, -2.44156151,
#         2.66371274,  3.31676168,  2.75548532, -0.5408601 , -2.46453261,
#        -3.86270272, -3.12923444, -1.15399035,  2.39530223,  1.93382728,
#         2.82429683,  2.64552794, -0.83450718, -1.33988065,  0.90440647,
#         1.52105167, -3.71337342, -0.03035215,  2.62165738,  2.32014575,
#         2.80259945, -1.22961614, -2.61464624, -0.59899861,  0.70881522,
#        -2.60389588, -2.8635928 ,  2.4327131 ,  1.42552966, -1.78986736,
#         1.68299562, -1.39212   ,  1.08146048,  2.0277439 , -1.69207636,
#         1.77960854,  1.98756248,  2.82657781, -1.16030321,  1.99952585,
#        -1.80433157, -1.68414197, -3.15958827,  4.70790554, -0.64309336,
#        -2.17132877,  1.42147029, -1.07168684,  0.5786248 , -0.53395927,
#        -1.59935741, -2.77180784,  1.81241298,  1.56873137,  3.8856178 ,
#        -2.96597941,  2.61023209,  1.51273913, -0.9993963 ,  1.41657004,
#        -2.18775403, -3.37436321,  1.92360861, -0.57819206,  0.13390253,
#        -0.75036722,  2.85979663, -1.78555844, -0.18270592,  1.42750366,
#        -3.22741591,  1.57322468,  1.12264604, -1.05583878,  1.26234383,
#        -2.47272279,  1.90371568,  2.21091603,  1.7148302 , -0.97943969,
#         2.74301829,  1.30178686,  2.35950771,  3.26784329,  2.55397545,
#         1.23813164,  2.78309204,  2.49319583,  1.61203502,  1.10532609,
#         1.06982708,  1.09003924,  0.97465656,  1.12950314,  3.23703547,
#         2.00962637,  2.44806382,  2.80546718,  2.61987842,  2.44046932,
#         2.42230211,  1.3357192 ,  2.99660425,  1.8529204 ,  2.03174169,
#         3.14795712,  1.26706523,  2.10102437,  2.15610002,  2.25323233,
#         2.84887527,  1.80073173,  1.70433415,  0.74080582,  2.77262021,
#         1.79485684,  4.36548359,  2.77963255,  0.57750707,  1.57153871,
#         0.74922871,  1.42491048,  1.09462807,  1.24862712,  1.42287527,
#         0.67456403,  1.03029987,  2.66074515,  1.76096059,  1.44323489])

# %%
X_res[:,1]
# Out:
# array([-2.52444767,  3.03342072, -1.15209199, -3.0005582 , -2.07748222,
#         2.38679925,  1.22578013, -1.93182759, -1.64344828,  3.22430277,
#         2.81348316, -2.8144934 ,  0.75832195, -1.93006905,  0.93905178,
#        -3.46390114,  2.19021219,  0.50539897, -1.36631323, -2.44156151,
#         2.66371274,  3.31676168,  2.75548532, -0.5408601 , -2.46453261,
#        -3.86270272, -3.12923444, -1.15399035,  2.39530223,  1.93382728,
#         2.82429683,  2.64552794, -0.83450718, -1.33988065,  0.90440647,
#         1.52105167, -3.71337342, -0.03035215,  2.62165738,  2.32014575,
#         2.80259945, -1.22961614, -2.61464624, -0.59899861,  0.70881522,
#        -2.60389588, -2.8635928 ,  2.4327131 ,  1.42552966, -1.78986736,
#         1.68299562, -1.39212   ,  1.08146048,  2.0277439 , -1.69207636,
#         1.77960854,  1.98756248,  2.82657781, -1.16030321,  1.99952585,
#        -1.80433157, -1.68414197, -3.15958827,  4.70790554, -0.64309336,
#        -2.17132877,  1.42147029, -1.07168684,  0.5786248 , -0.53395927,
#        -1.59935741, -2.77180784,  1.81241298,  1.56873137,  3.8856178 ,
#        -2.96597941,  2.61023209,  1.51273913, -0.9993963 ,  1.41657004,
#        -2.18775403, -3.37436321,  1.92360861, -0.57819206,  0.13390253,
#        -0.75036722,  2.85979663, -1.78555844, -0.18270592,  1.42750366,
#        -3.22741591,  1.57322468,  1.12264604, -1.05583878,  1.26234383,
#        -2.47272279,  1.90371568,  2.21091603,  1.7148302 , -0.97943969,
#         2.74301829,  1.30178686,  2.35950771,  3.26784329,  2.55397545,
#         1.23813164,  2.78309204,  2.49319583,  1.61203502,  1.10532609,
#         1.06982708,  1.09003924,  0.97465656,  1.12950314,  3.23703547,
#         2.00962637,  2.44806382,  2.80546718,  2.61987842,  2.44046932,
#         2.42230211,  1.3357192 ,  2.99660425,  1.8529204 ,  2.03174169,
#         3.14795712,  1.26706523,  2.10102437,  2.15610002,  2.25323233,
#         2.84887527,  1.80073173,  1.70433415,  0.74080582,  2.77262021,
#         1.79485684,  4.36548359,  2.77963255,  0.57750707,  1.57153871,
#         0.74922871,  1.42491048,  1.09462807,  1.24862712,  1.42287527,
#         0.67456403,  1.03029987,  2.66074515,  1.76096059,  1.44323489])

# %%
import matplotlib.pyplot as plt
plt.scatter(X_res[:, 0], X_res[:, 2], marker='^', c=y_res)
